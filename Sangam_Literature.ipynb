# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !apt-get update && apt-get install -y poppler-utils
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,801 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,750 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,587 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,067 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,040 kB]
# Get:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,257 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:16 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,909 kB]
# Get:18 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [46.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,564 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,399 kB]
# Fetched 32.8 MB in 3s (9,776 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.8 [186 kB]
# Fetched 186 kB in 1s (223 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126308 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.8_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.8) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.8) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.5)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 33.9 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 37.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed emoji-2.14.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1

# %%
import stanza
import numpy as np
import re
from collections import defaultdict
import uuid

# %%
stanza.download('ta', verbose=False)
stanza.download('en', verbose=False)
nlp_tamil = stanza.Pipeline('ta', processors='tokenize,pos', verbose=False)
nlp_english = stanza.Pipeline('en', processors='tokenize,pos,ner', verbose=False)

# %%
pdf_path = '/content/drive/MyDrive/Journals/Ponniyan Selvan Part1.pdf'
text_output_path = 'extracted_text.txt'
# !pdftotext "{pdf_path}" "{text_output_path}"

# %%
def apply_nlp(text, language='en'):
    nlp = nlp_english if language == 'en' else nlp_tamil
    doc = nlp(text)
    return [
        [{
            'text': token.text,
            'pos': token.pos,
            # Access 'ner' attribute only if it exists for the token
            'ner': token.ner if hasattr(token, 'ner') else 'O'
        } for token in sent.words]
        for sent in doc.sentences
    ]

# %%
def is_boilerplate_line(line):
    common_noise = [
    r'உடம்பதாட\.',
    r'https://pandianeducationaltrust\.com/-chenkaantal\.html\.',
    r'திருக்குறள்\.',
    r'ஓராண்டிற்கு',
    r'©\.'
]
    return any(re.search(p, line, re.IGNORECASE) for p in common_noise)

# %%
def pos_tag_with_stanza(text):
    doc = nlp(text)
    tagged = []
    for sent in doc.sentences:
        for word in sent.words:
            tagged.append((word.text, word.upos))
    return tagged

# %%
def remove_boilerplate(text):
    boilerplate_patterns = [
        r'Bi-Yearly Peer-Reviewed Tamil Jowrmal',
        r'Volume - \d+, Issue - \d+, [A-Za-z]+ \d{4}',
        r'E-ISSN: \d{4}-\d{4}',
        r'DOI: 10\.\d+/zenodo\.\d+',
        r'Received \d+ [A-Za-z]+ \d{4};.*Available online \d+ [A-Za-z]+ \d{4}\.',
        r'Author Contribution Statement:.*?\n',
        r'Author Acknowledgement:.*?\n',
        r'Author Declaration:.*?\n',
        r'\(6\) The content of the article is licensed under.*?\n',
        r'Be Eco-Friendly',
        r'Available at: http://nandianeducationaltrust\.com/chenkaantal\.html',
        r'ORCID: https://orcid\.org/\d{4}-\d{4}-\d{4}-\d{4}',
    ]
    for pattern in boilerplate_patterns:
        text = re.sub(pattern, '', text, flags=re.MULTILINE)
    return text.strip()

# %%
def remove_non_tamil_content(text):
    # Keep Tamil (Unicode range: \u0B80-\u0BFF), English (ASCII), and basic punctuation
    pattern = r'[^\u0B80-\u0BFFa-zA-Z0-9\s.,;:"\'()-\[\]]'
    text = re.sub(pattern, '', text)
    return text

# %%
def remove_numbers_except_years(text):
    # Replace numbers not part of a 4-digit year (1900-2099)
    text = re.sub(r'\b(?!19\d{2}|20\d{2})\d+\b', '', text)
    return text

# %%
def process_nlp(text, lang='ta'):
    nlp = nlp_ta
    doc = nlp(text)
    sentences = []
    for sent in doc.sentences:
        tokens = []
        for token in sent.words:
            tokens.append({
                'text': token.text,
                'pos': token.pos,
                'ner': token.ner if hasattr(token, 'ner') else 'O'
            })
        sentences.append(tokens)
    return sentences

# %%
def rule_based_ner(sentences):
    literature_entities = ['Thirukkural', 'Tolkappiyam', 'Tholkappiya Porulathikaram', 'Akananooru']
    for sentence in sentences:
        for token in sentence:
            if token['text'] in literature_entities:
                token['ner'] = 'LITERATURE'
    return sentences

# %%
def entity_linking(sentences):
    knowledge_base = {
        'Thirukkural': 'A classic Tamil text by Thiruvalluvar',
        'Tolkappiyam': 'An ancient Tamil grammar and literature text',
        'Tholkappiya Porulathikaram': 'A section of Tolkappiyam on poetics',
        'Akananooru': 'A classical Tamil poetic work'
    }
    for sentence in sentences:
        for token in sentence:
            if token['ner'] == 'LITERATURE' and token['text'] in knowledge_base:
                token['entity_link'] = knowledge_base[token['text']]
    return sentences

# %%
def deduplicate_sentences(sentences):
    seen = set()
    deduped = []
    for sentence in sentences:
        sent_text = ' '.join([token['text'] for token in sentence])
        if sent_text not in seen:
            seen.add(sent_text)
            deduped.append(sentence)
    return deduped

# %%
def nlp_pipeline(text):
    text = remove_boilerplate(text)
    text = remove_non_tamil_content(text)
    text = remove_numbers_except_years(text)
    sentences = process_nlp(text, lang='ta')
    sentences = rule_based_ner(sentences)
    sentences = entity_linking(sentences)
    sentences = deduplicate_sentences(sentences)
    return sentences

# %%
def process_nlp(text, lang='ta'):
    # Use nlp_tamil for Tamil language processing
    nlp = nlp_tamil
    doc = nlp(text)
    sentences = []
    for sent in doc.sentences:
        tokens = []
        for token in sent.words:
            tokens.append({
                'text': token.text,
                'pos': token.pos,
                'ner': token.ner if hasattr(token, 'ner') else 'O'
            })
        sentences.append(tokens)
    return sentences

# %%
with open(text_output_path, 'r', encoding='utf-8') as f:
    pdf_text = f.read()

# %%
processed_sentences = nlp_pipeline(pdf_text)

# %%
for i, sentence in enumerate(processed_sentences):
    print(f"Sentence {i+1}:")
    for token in sentence:
        print(f"Token: {token['text']}, POS: {token['pos']}, NER: {token['ner']}, Entity Link: {token.get('entity_link', 'None')}")
    print()
# Out:
# Sentence 1:
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: (, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ), POS: PUNCT, NER: O, Entity Link: None
# Token: kalkiyi, POS: PROPN, NER: O, Entity Link: None
# Token: n2, POS: PROPN, NER: O, Entity Link: None
# Token: ponniyin, POS: PROPN, NER: O, Entity Link: None
# Token: celvan, POS: PROPN, NER: O, Entity Link: None
# Token: part-1, POS: NUM, NER: O, Entity Link: None
# Token: a, POS: PUNCT, NER: O, Entity Link: None
# Token: putu, POS: PUNCT, NER: O, Entity Link: None
# Token: veLLam, POS: PROPN, NER: O, Entity Link: None
# Token: (, POS: PUNCT, NER: O, Entity Link: None
# Token: chapters, POS: PROPN, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ), POS: PUNCT, NER: O, Entity Link: None
# Token: in, POS: PUNCT, NER: O, Entity Link: None
# Token: tamil, POS: PUNCT, NER: O, Entity Link: None
# Token: script, POS: NOUN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: TSCII, POS: NOUN, NER: O, Entity Link: None
# Token: forma, POS: VERB, NER: O, Entity Link: None
# Token: t, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 2:
# Token: Etext, POS: PUNCT, NER: O, Entity Link: None
# Token: in, POS: PUNCT, NER: O, Entity Link: None
# Token: Tamil, POS: PROPN, NER: O, Entity Link: None
# Token: Script, POS: NOUN, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: TSCII, POS: NOUN, NER: O, Entity Link: None
# Token: format, POS: NOUN, NER: O, Entity Link: None
# Token: (, POS: PUNCT, NER: O, Entity Link: None
# Token: v., POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ), POS: PUNCT, NER: O, Entity Link: None
# Token: Etext, POS: NOUN, NER: O, Entity Link: None
# Token: preparat், POS: PROPN, NER: O, Entity Link: None
# Token: ஆnn, POS: ADP, NER: O, Entity Link: None
# Token: :, POS: PUNCT, NER: O, Entity Link: None
# Token: Mr., POS: PROPN, NER: O, Entity Link: None
# Token: Bhaskaran, POS: PROPN, NER: O, Entity Link: None
# Token: Sankaran, POS: PROPN, NER: O, Entity Link: None
# Token: and, POS: PUNCT, NER: O, Entity Link: None
# Token: colleagues, POS: PROPN, NER: O, Entity Link: None
# Token: of, POS: NOUN, NER: O, Entity Link: None
# Token: Anna, POS: PROPN, NER: O, Entity Link: None
# Token: University, POS: NOUN, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: KBC, POS: PROPN, NER: O, Entity Link: None
# Token: Researc, POS: PROPN, NER: O, Entity Link: None
# Token: h, POS: NOUN, NER: O, Entity Link: None
# Token: Center, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: MIT, POS: PROPN, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: Chrompe, POS: PROPN, NER: O, Entity Link: None
# Token: t, POS: PROPN, NER: O, Entity Link: None
# Token: Campus, POS: NOUN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Chennai, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: India, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: Proof-reading, POS: PROPN, NER: O, Entity Link: None
# Token: :, POS: PUNCT, NER: O, Entity Link: None
# Token: Mr., POS: PROPN, NER: O, Entity Link: None
# Token: S., POS: PUNCT, NER: O, Entity Link: None
# Token: Anbum், POS: PROPN, NER: O, Entity Link: None
# Token: ஆii, POS: NOUN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Mr., POS: PROPN, NER: O, Entity Link: None
# Token: N.D., POS: PROPN, NER: O, Entity Link: None
# Token: Logasundaram, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Mr., POS: PROPN, NER: O, Entity Link: None
# Token: Narayanan, POS: PROPN, NER: O, Entity Link: None
# Token: Govindarajan, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Ms., POS: PROPN, NER: O, Entity Link: None
# Token: Pavithra, POS: PROPN, NER: O, Entity Link: None
# Token: Srinivasan, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Mr., POS: PROPN, NER: O, Entity Link: None
# Token: Ramachandra, POS: PROPN, NER: O, Entity Link: None
# Token: n, POS: PROPN, NER: O, Entity Link: None
# Token: Mahadevan, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Ms., POS: PROPN, NER: O, Entity Link: None
# Token: Sathya, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Mr., POS: PROPN, NER: O, Entity Link: None
# Token: Sreeram, POS: PROPN, NER: O, Entity Link: None
# Token: Krishnamoo், POS: PROPN, NER: O, Entity Link: None
# Token: ஆhy, POS: NOUN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Dr., POS: PROPN, NER: O, Entity Link: None
# Token: Sridhar, POS: PROPN, NER: O, Entity Link: None
# Token: Rathinam, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Mrs., POS: PROPN, NER: O, Entity Link: None
# Token: Srilatha, POS: PROPN, NER: O, Entity Link: None
# Token: Rajagopal, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Mr., POS: PROPN, NER: O, Entity Link: None
# Token: Vinoth, POS: PROPN, NER: O, Entity Link: None
# Token: Jagannathan, POS: PROPN, NER: O, Entity Link: None
# Token: Etext, POS: NOUN, NER: O, Entity Link: None
# Token: prep, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 3:
# Token: in, POS: PROPN, NER: O, Entity Link: None
# Token: html/web, POS: PROPN, NER: O, Entity Link: None
# Token: version, POS: NOUN, NER: O, Entity Link: None
# Token: :, POS: PUNCT, NER: O, Entity Link: None
# Token: Mr., POS: PROPN, NER: O, Entity Link: None
# Token: S., POS: PROPN, NER: O, Entity Link: None
# Token: Anbum், POS: PUNCT, NER: O, Entity Link: None
# Token: ஆii, POS: NOUN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Blacksburg, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Virginia, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: USA, POS: PROPN, NER: O, Entity Link: None
# Token: Etext, POS: PUNCT, NER: O, Entity Link: None
# Token: prep, POS: PROPN, NER: O, Entity Link: None
# Token: in, POS: PROPN, NER: O, Entity Link: None
# Token: pdf, POS: NOUN, NER: O, Entity Link: None
# Token: format, POS: NOUN, NER: O, Entity Link: None
# Token: :, POS: PUNCT, NER: O, Entity Link: None
# Token: Dr., POS: PROPN, NER: O, Entity Link: None
# Token: K., POS: PUNCT, NER: O, Entity Link: None
# Token: Kalyanasu், POS: PROPN, NER: O, Entity Link: None
# Token: ஆaa, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Lausanne, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Switzerlan, POS: PROPN, NER: O, Entity Link: None
# Token: d, POS: PROPN, NER: O, Entity Link: None
# Token: This, POS: PROPN, NER: O, Entity Link: None
# Token: pdf, POS: NOUN, NER: O, Entity Link: None
# Token: file, POS: PUNCT, NER: O, Entity Link: None
# Token: is, POS: PROPN, NER: O, Entity Link: None
# Token: based, POS: ADJ, NER: O, Entity Link: None
# Token: on, POS: NOUN, NER: O, Entity Link: None
# Token: TSCInaim், POS: PROPN, NER: O, Entity Link: None
# Token: ஆhi, POS: NOUN, NER: O, Entity Link: None
# Token: font, POS: PROPN, NER: O, Entity Link: None
# Token: embedded, POS: PROPN, NER: O, Entity Link: None
# Token: in, POS: NOUN, NER: O, Entity Link: None
# Token: the, POS: NOUN, NER: O, Entity Link: None
# Token: file, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 4:
# Token: Hence, POS: PROPN, NER: O, Entity Link: None
# Token: this, POS: NOUN, NER: O, Entity Link: None
# Token: file, POS: PUNCT, NER: O, Entity Link: None
# Token: can, POS: PROPN, NER: O, Entity Link: None
# Token: be, POS: NOUN, NER: O, Entity Link: None
# Token: viewed, POS: NOUN, NER: O, Entity Link: None
# Token: and, POS: PUNCT, NER: O, Entity Link: None
# Token: printed, POS: NOUN, NER: O, Entity Link: None
# Token: on, POS: NOUN, NER: O, Entity Link: None
# Token: all, POS: PROPN, NER: O, Entity Link: None
# Token: computer, POS: NOUN, NER: O, Entity Link: None
# Token: platforms, POS: NOUN, NER: O, Entity Link: None
# Token: :, POS: PUNCT, NER: O, Entity Link: None
# Token: Windows, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: Macintos, POS: PROPN, NER: O, Entity Link: None
# Token: h, POS: NOUN, NER: O, Entity Link: None
# Token: and, POS: PUNCT, NER: O, Entity Link: None
# Token: Unix, POS: PROPN, NER: O, Entity Link: None
# Token: without, POS: NOUN, NER: O, Entity Link: None
# Token: the, POS: NOUN, NER: O, Entity Link: None
# Token: need, POS: NOUN, NER: O, Entity Link: None
# Token: to, POS: NOUN, NER: O, Entity Link: None
# Token: have, POS: NOUN, NER: O, Entity Link: None
# Token: the, POS: NOUN, NER: O, Entity Link: None
# Token: font, POS: PROPN, NER: O, Entity Link: None
# Token: installed, POS: NOUN, NER: O, Entity Link: None
# Token: in, POS: PUNCT, NER: O, Entity Link: None
# Token: your, POS: NOUN, NER: O, Entity Link: None
# Token: computer, POS: NOUN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 5:
# Token: Project, POS: PROPN, NER: O, Entity Link: None
# Token: Madurai, POS: PROPN, NER: O, Entity Link: None
# Token: 2003, POS: NUM, NER: O, Entity Link: None
# Token: You, POS: NOUN, NER: O, Entity Link: None
# Token: are, POS: PROPN, NER: O, Entity Link: None
# Token: welcome, POS: NOUN, NER: O, Entity Link: None
# Token: to, POS: NOUN, NER: O, Entity Link: None
# Token: freely, POS: NOUN, NER: O, Entity Link: None
# Token: distribute, POS: NOUN, NER: O, Entity Link: None
# Token: this, POS: NOUN, NER: O, Entity Link: None
# Token: file, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: provided, POS: PROPN, NER: O, Entity Link: None
# Token: this, POS: NOUN, NER: O, Entity Link: None
# Token: header, POS: PROPN, NER: O, Entity Link: None
# Token: page, POS: NOUN, NER: O, Entity Link: None
# Token: is, POS: PROPN, NER: O, Entity Link: None
# Token: kept, POS: NOUN, NER: O, Entity Link: None
# Token: intact, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 6:
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 7:
# Token: -, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 8:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: (, POS: PUNCT, NER: O, Entity Link: None
# Token: 1950, POS: NUM, NER: O, Entity Link: None
# Token: ), POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 9:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 10:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 11:
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 12:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 13:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 14:
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 15:
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 16:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 17:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 18:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 19:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 20:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 21:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 22:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 23:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 24:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 25:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 26:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 27:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 28:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 29:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 30:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 31:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 32:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 33:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ;, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 34:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 35:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 36:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 37:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 38:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: -----, POS: NUM, NER: O, Entity Link: None
#
# Sentence 39:
# Token: ------, POS: NUM, NER: O, Entity Link: None
#
# Sentence 40:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 41:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 42:
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ;, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 43:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 44:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 45:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 46:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: :, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 47:
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 48:
# Token: :, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 49:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 50:
# Token: ...., POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 51:
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: '', POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: '', POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: '', POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: '', POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 52:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ..., POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 53:
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 54:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 55:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ..., POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 56:
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 57:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 58:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 59:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 60:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 61:
# Token: '', POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: '', POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 62:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ------, POS: NUM, NER: O, Entity Link: None
#
# Sentence 63:
# Token: ----, POS: NUM, NER: O, Entity Link: None
#
# Sentence 64:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 65:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 66:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 67:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 68:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 69:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 70:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: .', POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?', POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 71:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: .., POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 72:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: .", POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 73:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 74:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 75:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: "., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: "., POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 76:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 77:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 78:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# ...
#
# Sentence 574:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 575:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ..., POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ...", POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ...., POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 576:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: '', POS: PROPN, NER: O, Entity Link: None
# Token: '', POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 577:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 578:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 579:
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ..., POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 580:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 581:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ..., POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 582:
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 583:
# Token: ..., POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ...", POS: PROPN, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 584:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 585:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: --------, POS: NUM, NER: O, Entity Link: None
#
# Sentence 586:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 587:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 588:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: --, POS: NUM, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 589:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 590:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 591:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: --, POS: NUM, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ', POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 592:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ?, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 593:
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ***************, POS: PROPN, NER: O, Entity Link: None
# Token: *, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 594:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 595:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 596:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 597:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 598:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 599:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 600:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: '', POS: PROPN, NER: O, Entity Link: None
# Token: :, POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 601:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ", POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 602:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 603:
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 604:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ,, POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
#
# Sentence 605:
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: ;, POS: PROPN, NER: O, Entity Link: None
# Token: ., POS: PUNCT, NER: O, Entity Link: None
# Token: -, POS: PUNCT, NER: O, Entity Link: None
# Token: ------, POS: NUM, NER: O, Entity Link: None

# %%
with open(text_output_path, 'r', encoding='utf-8') as f:
    pdf_text = f.read()

# %%
# Execute Pipeline
processed_data = nlp_pipeline(pdf_path)

# %%
# Display Results
for idx, sentence in enumerate(processed_data, 1):
    print(f"Sentence {idx}:")
    for token in sentence:
        print(f"  Token: {token['text']}, POS: {token['pos']}, NER: {token['ner']}, Entity Link: {token.get('entity_link', 'None')}")
    print()
# Out:
# Sentence 1:
#   Token: /content/drive/MyDrive/Journals/Ponniyan, POS: PART, NER: O, Entity Link: None
#   Token: Selvan, POS: PROPN, NER: O, Entity Link: None
#   Token: Part1.pd, POS: PROPN, NER: O, Entity Link: None
#   Token: f, POS: PUNCT, NER: O, Entity Link: None

# %%
with open('nlp_output.txt', 'w', encoding='utf-8') as output_file:
    for idx, sentence in enumerate(processed_data, 1):
        output_file.write(f"Sentence {idx}:\n")
        for token in sentence:
            output_file.write(f"  Token: {token['text']}, POS: {token['pos']}, NER: {token['ner']}, Entity Link: {token.get('entity_link', 'None')}\n")
        output_file.write("\n")

# %%
# !pip install indic-nlp-library pdfplumber wikipedia-api --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 54.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 4.8 MB/s eta 0:00:00
#   Building wheel for wikipedia-api (setup.py) ... done

# %%
# !python -m indicnlp.resources.manager download_resources
# Out:
# /usr/bin/python3: Error while finding module specification for 'indicnlp.resources.manager' (ModuleNotFoundError: No module named 'indicnlp.resources')

# %%
import pdfplumber
import re, wikipediaapi
from indicnlp import loader
from indicnlp.tokenize import sentence_tokenize, indic_tokenize

# %%
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_resources.git
# Out:
# Cloning into 'indic_nlp_resources'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 139 (delta 2), reused 2 (delta 0), pack-reused 126 (from 1)
# Receiving objects: 100% (139/139), 149.77 MiB | 24.19 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# Updating files: 100% (28/28), done.

# %%
INDIC_NLP_LIB_HOME = '/usr/local/lib/python3.11/dist-packages/indicnlp'
INDIC_NLP_RESOURCES = '/content/indic_nlp_resources'

# %%
GAZETTEER_PERSONS = {'அருள்மொழி', 'வந்தியத்தேவன்', 'நந்தினி'}
GAZETTEER_PLACES = {'தஞ்சாவூர்', 'காஞ்சிபுரம்'}

# %%
BOILERPLATE_PATTERNS = [
    r'Project Madurai.*?\n', r'Etext.*?\n', r'www.*?\s', r'https?://\S+'
]

# %%
pdf_path = '/content/drive/MyDrive/Journals/Ponniyan Selvan Part1.pdf'

# %%
def extract_text(pdf):
    text = ''
    with pdfplumber.open(pdf) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text += '\n' + page_text
    return text

# %%
def remove_boilerplate(text):
    for pattern in BOILERPLATE_PATTERNS:
        text = re.sub(pattern, '', text, flags=re.IGNORECASE)
    return text

# %%
def remove_non_tamil(text):
    return ' '.join([w for w in text.split() if re.search(r'[\u0B80-\u0BFF]', w)])

# %%
def remove_numbers_but_keep_years(text):
    return ' '.join([w for w in text.split() if not (w.isdigit() and not 1000 <= int(w) <= 2100)])

# %%
NOUN_SUFFIXES, VERB_SUFFIXES, PRONOUNS = ['க்கு', 'இல்'], ['கிறான்'], ['நான்', 'நீ']

# %%
def pos_tag(token):
    if token in PRONOUNS: return 'PRONOUN'
    if any(token.endswith(s) for s in NOUN_SUFFIXES): return 'NOUN'
    if any(token.endswith(s) for s in VERB_SUFFIXES): return 'VERB'
    return 'OTHER'

# %%
def ner_tag(token, next_token=None):
    if token in GAZETTEER_PERSONS: return 'PERSON'
    if token in GAZETTEER_PLACES: return 'LOCATION'
    if next_token in ['நகரம்', 'மாவட்டம்']: return 'POSSIBLE_LOCATION'
    return 'O'

# %%
wiki_ta = wikipediaapi.Wikipedia(user_agent='MyTamilNLPApp/1.0 (https://example.com/myappinfo)', language='ta')

# %%
def entity_link(entity):
    page = wiki_ta.page(entity)
    return page.fullurl if page.exists() else None

# %%
def deduplicate_sentences(sent_list):
    return list(dict.fromkeys(sent_list))

# %%
text = extract_text(pdf_path)
text = remove_boilerplate(text)
text = remove_non_tamil(text)
text = remove_numbers_but_keep_years(text)
sentences = sentence_tokenize.sentence_split(text, lang='ta')
sentences = deduplicate_sentences(sentences)

# %%
# Deduplication
def deduplicate_sentences(sentences):
    return list(dict.fromkeys(sentences))

# %%
for sent in sentences:
    tokens = indic_tokenize.trivial_tokenize(sent, lang='ta')
    print(f"\nSentence: {sent.strip()}")
    for idx, tok in enumerate(tokens):
        pos = pos_tag(tok)
        next_tok = tokens[idx+1] if idx+1 < len(tokens) else None
        ner = ner_tag(tok, next_tok)
        link = entity_link(tok) if ner in ['PERSON', 'LOCATION'] else None
        print(f"{tok:15} | POS: {pos:8} | NER: {ner:10} | Link: {link}")

# %%
# !apt-get install -y tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
# !pip install pdfplumber pytesseract indic-nlp-library wikipedia-api --quiet

# %%
import pdfplumber
import pytesseract
import re, wikipediaapi
from PIL import Image
from indicnlp import loader
from indicnlp.tokenize import sentence_tokenize, indic_tokenize

# %%
INDIC_NLP_LIB_HOME = '/usr/local/lib/python3.11/dist-packages/indicnlp'
INDIC_NLP_RESOURCES = '/usr/local/lib/python3.11/dist-packages/indicnlp/resources'

# %%
GAZETTEER_PERSONS = {'அருள்மொழி', 'வந்தியத்தேவன்', 'நந்தினி'}
GAZETTEER_PLACES = {'தஞ்சாவூர்', 'காஞ்சிபுரம்'}

# %%
pdf_path = '/content/drive/MyDrive/Journals/Ponniyan Selvan Part1.pdf'

# %%
def extract_text_with_ocr(pdf):
    text = ''
    with pdfplumber.open(pdf) as pdf:
        for page in pdf.pages:
            # Try text layer first
            page_text = page.extract_text()
            if page_text and len(page_text.strip()) > 20:
                text += '\n' + page_text
            else:
                print(f"Page {page.page_number} has no text — using OCR.")
                pil_image = page.to_image(resolution=300).original
                ocr_text = pytesseract.image_to_string(pil_image, lang='tam')
                text += '\n' + ocr_text
    return text

# %%
def remove_boilerplate(text):
    patterns = [r'Project Madurai.*?\n', r'Etext.*?\n', r'www.*?\s', r'https?://\S+']
    for p in patterns: text = re.sub(p, '', text, flags=re.IGNORECASE)
    return text

# %%
def remove_non_tamil(text):
    return ' '.join([w for w in text.split() if re.search(r'[\u0B80-\u0BFF]', w)])

# %%
def remove_numbers_but_keep_years(text):
    return ' '.join([w for w in text.split() if not (w.isdigit() and not 1000 <= int(w) <= 2100)])

# %%
NOUN_SUFFIXES, VERB_SUFFIXES, PRONOUNS = ['க்கு', 'இல்'], ['கிறான்'], ['நான்', 'நீ']

# %%
def pos_tag(token):
    if token in PRONOUNS: return 'PRONOUN'
    if any(token.endswith(s) for s in NOUN_SUFFIXES): return 'NOUN'
    if any(token.endswith(s) for s in VERB_SUFFIXES): return 'VERB'
    return 'OTHER'

# %%
def ner_tag(token, next_token=None):
    if token in GAZETTEER_PERSONS: return 'PERSON'
    if token in GAZETTEER_PLACES: return 'LOCATION'
    if next_token in ['நகரம்', 'மாவட்டம்']: return 'POSSIBLE_LOCATION'
    return 'O'

# %%
wiki_ta = wikipediaapi.Wikipedia(user_agent='MyTamilNLPApp/1.0 (https://example.com/myappinfo)', language='ta')

# %%
def entity_link(entity):
    page = wiki_ta.page(entity)
    return page.fullurl if page.exists() else None

# %%
def deduplicate_sentences(sents):
  return list(dict.fromkeys(sents))

# %%
text = extract_text_with_ocr(pdf_path)
text = remove_boilerplate(text)
text = remove_non_tamil(text)
text = remove_numbers_but_keep_years(text)
sentences = sentence_tokenize.sentence_split(text, lang='ta')
sentences = deduplicate_sentences(sentences)

# %%
for sent in sentences:
    tokens = indic_tokenize.trivial_tokenize(sent, lang='ta')
    print(f"\nSentence: {sent.strip()}")
    for idx, tok in enumerate(tokens):
        pos = pos_tag(tok)
        next_tok = tokens[idx+1] if idx+1 < len(tokens) else None
        ner = ner_tag(tok, next_tok)
        link = entity_link(tok) if ner in ['PERSON', 'LOCATION'] else None
        print(f"{tok:15} | POS: {pos:8} | NER: {ner:10} | Link: {link}")
